# %%
file = open('test.txt','r')

the_matrix = []
for riga in file:
    riga_matrix = [riga[j] for j in range(len(riga.strip()))]
    the_matrix.append(riga_matrix)

# %%
the_matrix
# Out:
# [['.', '.', '.', '#', '.', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '#', '.', '.'],
#  ['#', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '#', '.', '.', '.'],
#  ['.', '#', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '#'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '#', '.', '.'],
#  ['#', '.', '.', '.', '#', '.', '.', '.', '.', '.']]

# %%
def expander(universo_matrix):
    print(len(universo_matrix))
    for i in range(len(universo_matrix)):

    for i, riga in enumerate(universo_matrix):
        if '#' not in riga:
            print('devo fare la riga: ', i)
            universo_matrix.insert(i-1, ['.' for j in range(len(riga))])
    return universo_matrix

# %%
print(the_matrix)
print(len(the_matrix))
# Out:
# [['.', '.', '.', '#', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '#', '.', '.'], ['#', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '#', '.', '.', '.'], ['.', '#', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.', '.', '#'], ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '#', '.', '.'], ['#', '.', '.', '.', '#', '.', '.', '.', '.', '.']]
# 10

# %%
stocazzo = expander(the_matrix)
# Out:
# 10
# devo fare la riga:  3
# devo fare la riga:  4
# devo fare la riga:  5
# devo fare la riga:  6
# devo fare la riga:  7
# devo fare la riga:  8
# devo fare la riga:  9
# devo fare la riga:  10
# devo fare la riga:  11
# devo fare la riga:  12
# devo fare la riga:  13
# devo fare la riga:  14
# devo fare la riga:  15
# devo fare la riga:  16
# devo fare la riga:  17
# devo fare la riga:  18
# devo fare la riga:  19
# devo fare la riga:  20
# devo fare la riga:  21
# devo fare la riga:  22
# devo fare la riga:  23
# devo fare la riga:  24
# devo fare la riga:  25
# devo fare la riga:  26
# devo fare la riga:  27
# devo fare la riga:  28
# devo fare la riga:  29
# devo fare la riga:  30
# devo fare la riga:  31
# devo fare la riga:  32
# devo fare la riga:  33
# devo fare la riga:  34
# devo fare la riga:  35
# devo fare la riga:  36
# devo fare la riga:  37
# devo fare la riga:  38
# devo fare la riga:  39
# devo fare la riga:  40
# devo fare la riga:  41
# devo fare la riga:  42
# ...

# %%
a = ['.' for k in range(5)]
print(a)
# Out:
# ['.', '.', '.', '.', '.']
